# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lokeshparab/gutenberg-books-and-metadata-2025")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\st\.cache\kagglehub\datasets\lokeshparab\gutenberg-books-and-metadata-2025\4.archive...
# 100%|██████████| 10.8G/10.8G [16:18<00:00, 11.8MB/s]
# Extracting files...
# Path to dataset files: C:\Users\st\.cache\kagglehub\datasets\lokeshparab\gutenberg-books-and-metadata-2025\versions\4
